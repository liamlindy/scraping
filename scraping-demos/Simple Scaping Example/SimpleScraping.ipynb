# %% [markdown]
# # Liam Lindy
# ### Simple Website Scraping Example
# ## geeks for geeks example

# %% [markdown]
# ## This demonstrates how to do this with a simple ```URLLib``` package.

# %%
# importing modules
import urllib.request 
# # from bs4 import BeautifulSoup
  
# providing url
url = "https://www.geeksforgeeks.org/how-to-automate-an-excel-sheet-in-python/?ref=feed"
  
# opening the url for reading
html = urllib.request.urlopen(url)
  
# parsing the html file
htmlParse = BeautifulSoup(html, 'html.parser')
  
# getting all the paragraphs
for para in htmlParse.find_all("p"):
    print(para.get_text())
# Out:
# Before you read this article and learn automation in Python….let’s watch a video of Christian Genco (a talented programmer and an entrepreneur) explaining the importance of coding by taking the example of automation.You might have laughed loudly after watching this video and you surely, you might have understood the importance of automation in real life as well. Let’s come to the topic now…We all know that Python is ruling all over the world, and we also know that Python is beginner’s friendly and it’s easy to learn in comparison to other languages. One of the best things you can do with Python is Automation. var adpushup = window.adpushup  = window.adpushup || {que:[]};adpushup.que.push(function() {adpushup.triggerAd("d6f45c53-ff16-4cc5-8b91-eb6ee7037116");});Consider a scenario that you’re asked to create an account on a website for 30,000 employees. How would you feel? Surely you will be frustrated doing this task manually and repeatedly. Also, this is going to take too much time 
# ...

# %% [markdown]
# ## This demonstrates it with Requests

# %%
# import module
import requests
import pandas as pd
from bs4 import BeautifulSoup

# link for extract html data


def getdata(url):
    r = requests.get(url)
    return r.text


htmldata = getdata(
    "https://www.geeksforgeeks.org/how-to-automate-an-excel-sheet-in-python/?ref=feed")
soup = BeautifulSoup(htmldata, 'html.parser')
data = ''
for data in soup.find_all("p"):
    print(data.get_text())
# Out:
# /Users/liamlindy/opt/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# ...

# %% [markdown]
# ## This demonstrates it with a sample HTML Page

# %%
import bs4 as BeautifulSoup
# import module
import requests
import pandas as pd
from bs4 import BeautifulSoup

f = open('liam-made-this.html')
html = f.read()

soup = BeautifulSoup(html, 'html.parser')
title = soup.title.get_text()
print('HTML Title:', title)

data = ''
for data in soup.find_all("p"):
    print(data.get_text())
# Out:
# HTML Title:  Liam is AMAZING!
#
#             Magna adipisicing consequat nulla excepteur eu dolore velit dolore nisi. Incididunt ad veniam dolore aliqua mollit aute dolor ex officia ex. Non deserunt labore non esse laboris sunt commodo laboris commodo eiusmod laboris. Ullamco occaecat ipsum commodo aliqua velit do elit incididunt veniam consectetur cupidatat aliqua.
#
#
#             Amet ut id id aliqua. Cupidatat irure exercitation voluptate anim velit. Irure excepteur minim laboris ad. Culpa irure do occaecat veniam nostrud.
#
# Proident ut minim nisi officia occaecat exercitation esse sint ipsum. Ad nisi irure in est culpa excepteur. Eiusmod sunt elit ad tempor nisi voluptate sint tempor est minim. Sit do aliquip mollit deserunt est sit incididunt reprehenderit deserunt nulla consequat.
#
# ...
